# %% [markdown]
# # Gaussian Boson Sampling (GBS) benchmark
#
# Small, runnable notebook to benchmark GBS on a local machine using Strawberry Fields and The Walrus.
#
# Sections:
# - Setup and imports
# - Small GBS run (N=4..8 modes)
# - Compute small-instance probabilities using The Walrus (hafnian)
# - Plot distributions and KL divergence vs a classical emulator

# %%
# Imports and quick checks
import numpy as np
import matplotlib.pyplot as plt
import json

import strawberryfields as sf
from strawberryfields.ops import Sgate, Interferometer, MeasureFock
from thewalrus import hafnian

print('numpy', np.__version__)
print('strawberryfields', sf.__version__)
