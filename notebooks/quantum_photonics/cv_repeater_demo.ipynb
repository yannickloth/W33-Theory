# %% [markdown]
# # CV entanglement distribution & repeater demo
#
# A small notebook to model TMSV states sent over lossy channels and a simple entanglement swapping node.

# %%
import numpy as np
from math import log
print('numpy', np.__version__)
